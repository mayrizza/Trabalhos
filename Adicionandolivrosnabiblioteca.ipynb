# %% [markdown]
# <a href="https://colab.research.google.com/github/mayrizza/Trabalhos/blob/main/Adicionandolivrosnabiblioteca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
#Classe para representar um livro
class Livro:
  def __init__(self, titulo, autor, ano_publicacao):
    self.titulo = titulo
    self.autor = autor
    self.ano_publicacao = ano_publicacao
  def __str__(self):
    return f"{self.titulo} por {self.autor}, Publicado em {self.ano_publicacao}"

# %%
#Criar uma lista de livros
biblioteca = []
#Função para adicionar um livro à biblioteca
def adicionar_livro(titulo, autor, ano_publicacao):
  novo_livro = Livro(titulo, autor, ano_publicacao)
  biblioteca.append(novo_livro)
  print(f"{titulo} foi adicionado á biblioteca.")
#Função para listar todos os livros na biblioteca
def listar_livros():
  print()
  for livro in biblioteca:
    print(livro)
#Adicionar alguns livros na biblioteca
adicionar_livro("Dom Casmurro", "Machado de Assis", 1899)
adicionar_livro("Crime e Castigo", "Fiódor Dostoiévski", 1866)
adicionar_livro("Orgulho e Preconceito", "Jane Austen", 1813)
adicionar_livro("O Senhor dos Anéis", "J.R.R Tolkien", 1954)
adicionar_livro("O Conto da Aia", "Margaret Atwood", 1985)
#Listar todos os livros na biblioteca
listar_livros()
# Out:
# Dom Casmurro foi adicionado á biblioteca.
# Crime e Castigo foi adicionado á biblioteca.
# Orgulho e Preconceito foi adicionado á biblioteca.
# O Senhor dos Anéis foi adicionado á biblioteca.
# O Conto da Aia foi adicionado á biblioteca.
#
# Dom Casmurro por Machado de Assis, Publicado em 1899
# Crime e Castigo por Fiódor Dostoiévski, Publicado em 1866
# Orgulho e Preconceito por Jane Austen, Publicado em 1813
# O Senhor dos Anéis por J.R.R Tolkien, Publicado em 1954
# O Conto da Aia por Margaret Atwood, Publicado em 1985

# %%
#Criar um gráfico de livros por ano
anos = [livro.ano_publicacao for livro in biblioteca]
anos = list(set(anos))
anos.sort()
#Contagem de livros por ano
contagem_por_ano = [anos.count(ano) for ano in anos]
#Criando um gráfico
plt.bar(anos, contagem_por_ano, color = "pink")
plt.xlabel("Ano")
plt.ylabel("Quantidade de livros")
plt.title("Distribuição de Livros na Biblioteca por Ano de Publicação")
plt.show()
